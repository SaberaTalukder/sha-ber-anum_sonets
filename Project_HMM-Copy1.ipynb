# %%
import os
import timeit

from HMM_george import unsupervised_HMM
from HMM_helper_processed import (
    text_to_wordcloud,
    states_to_wordclouds,
    parse_observations,
    parse_observations2,
    sample_sentence,
    visualize_sparsities,
    animate_emission
)

# %%
sonnets = open(os.path.join(os.getcwd(), 'data/shakespeare.txt')).read()
sonnets2 = open(os.path.join(os.getcwd(), 'data/spenser.txt')).read()
poem3 = open(os.path.join(os.getcwd(), 'data/poem3.txt')).read()
poem4 = open(os.path.join(os.getcwd(), 'data/poem4.txt')).read()
obs, obs_map = parse_observations(sonnets, sonnets2, poem3, poem4)

# %%
print(len(obs))
# print(obs[0])

print(len(obs_map))
print(obs_map)
# Out:
# 311
# 5673
# {'from': 0, 'fairest': 1, 'creatures': 2, 'we': 3, 'desire': 4, 'increase': 5, ',': 6, 'that': 7, 'thereby': 8, 'beauty^s': 9, 'rose': 10, 'might': 11, 'never': 12, 'die': 13, 'but': 14, 'as': 15, 'the': 16, 'riper': 17, 'should': 18, 'by': 19, 'time': 20, 'decease': 21, 'his': 22, 'tender': 23, 'heir': 24, 'bear': 25, 'memory': 26, 'thou': 27, 'contracted': 28, 'to': 29, 'thine': 30, 'own': 31, 'bright': 32, 'eyes': 33, 'feed^st': 34, 'thy': 35, 'light^s': 36, 'flame': 37, 'with': 38, 'self-substantial': 39, 'fuel': 40, 'making': 41, 'a': 42, 'famine': 43, 'where': 44, 'abundance': 45, 'lies': 46, 'self': 47, 'foe': 48, 'sweet': 49, 'too': 50, 'cruel': 51, 'art': 52, 'now': 53, 'world^s': 54, 'fresh': 55, 'ornament': 56, 'and': 57, 'only': 58, 'herald': 59, 'gaudy': 60, 'spring': 61, 'within': 62, 'bud': 63, 'buriest': 64, 'content': 65, 'churl': 66, 'mak^st': 67, 'waste': 68, 'in': 69, 'niggarding': 70, 'pity': 71, 'world': 72, 'or': 73, 'else': 74, 'this': 75, 'glutton': 76, 'be': 77, 'eat': 78, 'due': 79, 'grave': 80, 'thee': 81, '.': 82, 'when': 83, 'forty': 84, 'winters': 85, 'shall': 86, 'besiege': 87, 'brow': 88, 'dig': 89, 'deep': 90, 'trenches': 91, 'field': 92, 'youth^s': 93, 'proud': 94, 'livery': 95, 'so': 96, 'gazed': 97, 'on': 98, 'will': 99, 'tattered': 100, 'weed': 101, 'of': 102, 'small': 103, 'worth': 104, 'held': 105, 'then': 106, 'being': 107, 'asked': 108, 'all': 109, 'beauty': 110, 'treasure': 111, 'lusty': 112, 'days': 113, ';': 114, 'say': 115, 'sunken': 116, 'were': 117, 'an': 118, 'all-eating': 119, 'shame': 120, 'thriftless': 121, 'praise': 122, 'how': 123, 'much': 124, 'more': 125, 'deserved': 126, 'use': 127, 'if': 128, 'couldst': 129, 'answer': 130, '^this': 131, 'fair': 132, 'child': 133, 'mine': 134, 'sum': 135, 'my': 136, 'count': 137, 'make': 138, 'old': 139, 'excuse^': 140, 'proving': 141, 'succession': 142, 'new': 143, 'made': 144, 'see': 145, 'blood': 146, 'warm': 147, 'feel^st': 148, 'it': 149, 'cold': 150, 'look': 151, 'glass': 152, 'tell': 153, 'face': 154, 'viewest': 155, 'is': 156, 'form': 157, 'another': 158, 'whose': 159, 'repair': 160, 'not': 161, 'renewest': 162, 'dost': 163, 'beguile': 164, 'unbless': 165, 'some': 166, 'mother': 167, 'for': 168, 'she': 169, 'uneared': 170, 'womb': 171, 'disdains': 172, 'tillage': 173, 'husbandry': 174, '?': 175, 'who': 176, 'he': 177, 'fond': 178, 'tomb': 179, 'self-love': 180, 'stop': 181, 'posterity': 182, 'mother^s': 183, 'calls': 184, 'back': 185, 'lovely': 186, 'april': 187, 'her': 188, 'prime': 189, 'through': 190, 'windows': 191, 'age': 192, 'shalt': 193, 'despite': 194, 'wrinkles': 195, 'golden': 196, 'live': 197, 'remembered': 198, 'single': 199, 'image': 200, 'dies': 201, 'unthrifty': 202, 'loveliness': 203, 'why': 204, 'spend': 205, 'upon': 206, 'legacy': 207, 'nature^s': 208, 'bequest': 209, 'gives': 210, 'nothing': 211, 'doth': 212, 'lend': 213, 'frank': 214, 'lends': 215, 'those': 216, 'are': 217, 'free': 218, 'beauteous': 219, 'niggard': 220, 'abuse': 221, 'bounteous': 222, 'largess': 223, 'given': 224, 'give': 225, 'profitless': 226, 'usurer': 227, 'great': 228, 'sums': 229, 'yet': 230, 'canst': 231, 'having': 232, 'traffic': 233, 'alone': 234, 'deceive': 235, 'nature': 236, 'gone': 237, 'what': 238, 'acceptable': 239, 'audit': 240, 'leave': 241, 'unused': 242, 'must': 243, 'tombed': 244, 'which': 245, 'used': 246, 'lives': 247, 'th^': 248, 'executor': 249, 'hours': 250, 'gentle': 251, 'work': 252, 'did': 253, 'frame': 254, 'gaze': 255, 'every': 256, 'eye': 257, 'dwell': 258, 'play': 259, 'tyrants': 260, 'very': 261, 'same': 262, 'unfair': 263, 'fairly': 264, 'excel': 265, 'never-resting': 266, 'leads': 267, 'summer': 268, 'hideous': 269, 'winter': 270, 'confounds': 271, 'him': 272, 'there': 273, 'sap': 274, 'checked': 275, 'frost': 276, 'leaves': 277, 'quite': 278, 'o^er-snowed': 279, 'bareness': 280, 'summer^s': 281, 'distillation': 282, 'left': 283, 'liquid': 284, 'prisoner': 285, 'pent': 286, 'walls': 287, 'effect': 288, 'bere ...

# %%
num_hmm_hidden_states = [2**0, 2**1, 2**2, 2**3, 2**4, 2**5]
num_iters = 10

# %%
arrangement_of_words = [9, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 9, 9]

def train(observations, observation_map, num_hidden_states, num_iterations, arrangement_of_words, num_words = 115):
    start_time = timeit.default_timer()
    hmm = unsupervised_HMM(observations, num_hidden_states, num_iterations)
    stop_time = timeit.default_timer()
    print('Elpased time: ', stop_time - start_time)
    print('Sample Poem:\n====================')
    sentence = sample_sentence(hmm, observation_map, n_words=num_words)
    sentence_split_by_spaces = sentence.split()
    
    count = 0
    total_num_words_printed = 0
    for num_words in arrangement_of_words:
        if(count == 0):
            sent = " ".join(sentence_split_by_spaces[0:num_words])
            
        elif count > 0:
            sent = " ".join(sentence_split_by_spaces[total_num_words_printed: total_num_words_printed + num_words])
            
        print(sent)
        total_num_words_printed += num_words
        count += 1

# %%
# hyphens should be removed as words
# punctuation can't directly follow other punctuation
# If there is a single i, it needs to be capitalized
# remake carrots into apostrophes

# %%
num_hmm_hidden_states = [2**2, 2**3, 2**4, 2**5]
num_iters = 1000

for hidden_state in num_hmm_hidden_states:
    print('On HMM number: ', hidden_state)
    train(obs, obs_map, hidden_state, num_iters, arrangement_of_words, 115)
    print('')
# Out:
# On HMM number:  4
# On iteration number:  0
# On iteration number:  100
# On iteration number:  200
# On iteration number:  300
# On iteration number:  400
# On iteration number:  500
# On iteration number:  600
# On iteration number:  700
# On iteration number:  800
# On iteration number:  900
# Elpased time:  1523.92514554
# Sample Poem:
# ====================
# Evil ? you , been such . but vilest
# . of in with , then help fame
# , are , as remain thence in ,
# which away by hands ? that , in
# me feasts , , after , abhor ,
# join and if them . what but now
# , , and , , or him deceit
# stood such knows not spurring and when to
# that , , now , note . home
# those angry is of with so nests ,
# for when upon but but yet . all
# to returned her , concord desire , but
# then me ! that yet enforced ? , bear
# collatine^s stands old and that then by slaughter ,...
#
# On HMM number:  8
# On iteration number:  0
# On iteration number:  100
# On iteration number:  200
# On iteration number:  300
# On iteration number:  400
# On iteration number:  500
# On iteration number:  600
# On iteration number:  700
# On iteration number:  800
# On iteration number:  900
# Elpased time:  1519.7526815720003
# Sample Poem:
# ====================
# Can by yours thou in short mars there where
# thou in found what none as there i
# but of strain feeling for well though on
# do such thou stay in from against die
# for is with till in do proving from
# at woe this on life stol^n from in
# methinks i therefore at make mock leaving you
# time making and that i me in last
# by art let i in bids all do
# draw is let smear crown him upon may
# not art of since have i despite breast
# upon yet they i had i suit out
# stop before at peace should in he waiting thou
# thou wet i move whom with pitying through thou...
#
# On HMM number:  16
# On iteration number:  0
# On iteration number:  100
# On iteration number:  200
# On iteration number:  300
# On iteration number:  400
# On iteration number:  500
# On iteration number:  600
# On iteration number:  700
# On iteration number:  800
# On iteration number:  900
# Elpased time:  1756.8196026220003
# Sample Poem:
# ====================
# True pale the foul the the little the want
# at the the famine the the the that
# barns the thine the the the her her
# cherish her straying fond young his his her
# the air an the infect ^for this an
# her pattern the pillage - tearing the the
# the the the the the the his this
# whose clamours remain seeming the an being feareth
# decrees their return the purest whose the return
# the her the the the some - the
# her the our return spirits that her the
# all the - the proud the hell the
# their seldom increaseful thou their built stuff the those
# closed his her the the before the feareth the...
#
# On HMM number:  32
# On iteration number:  0
# On iteration number:  100
# On iteration number:  200
# On iteration number:  300
# On iteration number:  400
# On iteration number:  500
# On iteration number:  600
# On iteration number:  700
# On iteration number:  800
# On iteration number:  900
# Elpased time:  2390.6600048640003
# Sample Poem:
# ====================
# And yet o but but being but and where
# ah to none if or ah who to
# so o to who yet and so and
# for but and and who they light come
# clouds ^out which if thus light some envy
# but but he which even to that and
# and or to she as and like as
# even or that so which to from wretched
# ^why being beaten then she and and or
# and and to light will will for then
# starts o cease recounting but who ^o yet
# o o and that and and and himself
# now when sing when nor as and ^well proclaim^d
# and how when or o even and to o...
